# %% [markdown]
# <a href="https://colab.research.google.com/github/Yu1623/Dolphin-OCR-Demo/blob/main/OCR_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Set up DOLPHIN OCR
# !git clone https://github.com/ByteDance/Dolphin.git
# !git lfs install
# !git clone https://huggingface.co/ByteDance/Dolphin-1.5 ./hf_model
# Out:
# Cloning into 'Dolphin'...
# remote: Enumerating objects: 290, done.
# remote: Counting objects: 100% (177/177), done.
# remote: Compressing objects: 100% (141/141), done.
# remote: Total 290 (delta 123), reused 42 (delta 36), pack-reused 113 (from 3)
# Receiving objects: 100% (290/290), 11.95 MiB | 16.17 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# Git LFS initialized.
# Cloning into './hf_model'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 16 (delta 2), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (16/16), 986.43 KiB | 2.44 MiB/s, done.

# %%
# Download required libraries
! pip install numpy omegaconf==2.3.0 opencv-python opencv-python-headless pillow timm torch torchvision transformers==4.47.0 accelerate==1.6.0 pymupdf==1.26

# %%
# !python ./Dolphin/demo_page.py --model_path ./hf_model --save_dir ./results --input_path ./Dolphin/demo/page_imgs/page_1.png
# Out:
# 2025-11-02 03:27:43.252709: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762054063.272124    1733 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762054063.277942    1733 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762054063.292776    1733 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
