# %% [markdown]
# <a href="https://colab.research.google.com/github/Yu1623/Dolphin-OCR-Demo/blob/main/OCR_Dlphin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download code
# !git clone https://github.com/bytedance/Dolphin.git
# !git lfs install
# !git clone https://huggingface.co/ByteDance/Dolphin-1.5 ./hf_model
# Out:
# Cloning into 'Dolphin'...
# remote: Enumerating objects: 290, done.
# remote: Counting objects: 100% (177/177), done.
# remote: Compressing objects: 100% (141/141), done.
# remote: Total 290 (delta 123), reused 42 (delta 36), pack-reused 113 (from 3)
# Receiving objects: 100% (290/290), 11.95 MiB | 17.36 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# Git LFS initialized.
# Cloning into './hf_model'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 16 (delta 2), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (16/16), 986.43 KiB | 1.45 MiB/s, done.

# %%
# Install libraries by adapting requirements.txt in Dolphin repository
# !pip install -q pillow torch torchvision transformers omegaconf==2.3.0 accelerate==1.6.0 pymupdf==1.26
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.7/354.7 kB 30.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 95.3 MB/s eta 0:00:00

# %%
# Experiment Dlphin model on a sample document image
# !python ./Dolphin/demo_page.py --model_path ./hf_model --save_dir ./results --input_path ./Dolphin/demo/page_imgs/page_1.png
# Out:
# 2025-11-02 03:17:17.912457: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762053437.936491    2396 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762053437.946333    2396 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762053437.964730    2396 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
